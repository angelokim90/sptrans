# %%
import nbimporter
import time
from api_kafka_minio import chama_api  
from spark_minio_postgres import chama_spark 

while True:
    print("Executando chama_api()...")
    chama_api()
    #time.sleep(5)  
    print("Executando chama_spark()...")
    chama_spark()    
    print("Aguardando 10 minutos...")
    time.sleep(600)
# Out:
# Executando chama_api()...
# Enviado chunk 0 de 2
# Enviado chunk 1 de 2
# Executando chama_spark()...
# Nenhum arquivo 20250819 encontrado em raw/api/2025-08-19/. Aguardando 10s...
# Arquivos encontrados em raw/api/2025-08-19/:
# - Nome: api/2025-08-19/191165364942790_20250819-143113
# , Tamanho: 1012212 bytes
#
# Processando arquivo: s3a://raw/api/2025-08-19/191165364942790_20250819-143113
#
# Arquivo api/2025-08-19/191165364942790_20250819-143113
#  processado com sucesso.
# Aguardando 10 minutos...
# Executando chama_api()...
# Enviado chunk 0 de 2
# Enviado chunk 1 de 2
# Executando chama_spark()...
# Nenhum arquivo 20250819 encontrado em raw/api/2025-08-19/. Aguardando 10s...
# Arquivos encontrados em raw/api/2025-08-19/:
# - Nome: api/2025-08-19/191776465973607_20250819-144124
# , Tamanho: 1011425 bytes
#
# Processando arquivo: s3a://raw/api/2025-08-19/191776465973607_20250819-144124
#
# Arquivo api/2025-08-19/191776465973607_20250819-144124
#  processado com sucesso.
# ...
